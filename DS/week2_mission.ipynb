# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/corazzon/boostcourse-ds-510/master/data/medical_201909.csv.zip", low_memory=False)
df.shape
# Out:
# (91335, 39)

# %% [markdown]
# ## Q1

# %%
df.columns
# Out:
# Index(['상가업소번호', '상호명', '지점명', '상권업종대분류코드', '상권업종대분류명', '상권업종중분류코드',
#        '상권업종중분류명', '상권업종소분류코드', '상권업종소분류명', '표준산업분류코드', '표준산업분류명', '시도코드',
#        '시도명', '시군구코드', '시군구명', '행정동코드', '행정동명', '법정동코드', '법정동명', '지번코드',
#        '대지구분코드', '대지구분명', '지번본번지', '지번부번지', '지번주소', '도로명코드', '도로명', '건물본번지',
#        '건물부번지', '건물관리번호', '건물명', '도로명주소', '구우편번호', '신우편번호', '동정보', '층정보',
#        '호정보', '경도', '위도'],
#       dtype='object')

# %%
df_p = df.loc[df['상권업종소분류명'] == '약국']

# %%
df_g = df_p.groupby('시도명').size()

# %%
df_g.sort_values(ascending=False)
# Out:
# 시도명
# 경기도        4510
# 서울특별시      3579
# 부산광역시      1130
# 경상남도       1017
# 인천광역시      1002
# 경상북도        915
# 대구광역시       870
# 전라북도        862
# 충청남도        830
# 전라남도        811
# 강원도         729
# 광주광역시       691
# 충청북도        648
# 대전광역시       603
# 울산광역시       362
# 제주특별자치도     226
# 세종특별자치시      99
# dtype: int64

# %% [markdown]
# ## Q2

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 데이터프레임이 df라는 이름으로 존재한다고 가정

# 병원, 약국, 동물병원 필터링
hospital_pharmacy = df[df['상권업종소분류명'] =='동물병원']

# %%
hospital_pharmacy['상권업종소분류명'].value_counts()
# Out:
# 상권업종소분류명
# 동물병원    3098
# Name: count, dtype: int64

# %%
df_hg = hospital_pharmacy.groupby('시도명').size()

# %%
df_hg.sort_values(ascending=False)
# Out:
# 시도명
# 경기도        992
# 서울특별시      557
# 인천광역시      193
# 경상북도       165
# 경상남도       161
# 부산광역시      153
# 충청남도       131
# 대구광역시      119
# 전라북도       111
# 강원도         85
# 전라남도        77
# 대전광역시       77
# 충청북도        75
# 광주광역시       71
# 울산광역시       61
# 제주특별자치도     46
# 세종특별자치시     13
# dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

# 한글 폰트 설정
font_path = 'C:/Windows/Fonts/NanumGothic.ttf'  # Windows 시스템의 경우
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

# %%
# 두 데이터프레임을 하나로 합치기
df_combined = pd.concat([df_g, df_hg], axis=1)
df_combined['총합'] = df_combined.sum(axis=1)
df_combined = df_combined.sort_values(by='총합', ascending=False).drop(columns='총합')
# 시각화
df_combined.plot(kind='bar', figsize=(12, 8))
plt.title('시도별 병원 및 약국 수')
plt.xlabel('시도명')
plt.ylabel('수')
plt.xticks(rotation=45)
plt.legend(title='상권업종')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Q3

# %%
df = df[(df['시도명'] == '서울특별시') & (df['상권업종중분류명'] == '병원')]

# %%
df.head(3)
# Out:
#      상가업소번호       상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명 상권업종소분류코드  \
# 1  20024149  타워광명내과의원  NaN         S       의료       S01       병원    S01B07
# 8  20808534    코원성형외과  NaN         S       의료       S01       병원    S01B08
# 9  20755460  헬로스마일소아과  NaN         S       의료       S01       병원    S01B11
#
#   상권업종소분류명 표준산업분류코드  ...                     건물관리번호   건물명  \
# 1    내과/외과   Q86201  ...  1168011800104670014000001   NaN
# 8  정형/성형외과   Q86201  ...  1168010700105920004010990  이가빌딩
# 9      소아과   Q86201  ...  1168010800100390018000001  성도빌딩
#
#                   도로명주소     구우편번호   신우편번호  동정보 층정보  호정보          경도         위도
# 1   서울특별시 강남구 언주로30길 39  135270.0  6292.0  NaN   4  NaN  127.053198  37.488742
# 8     서울특별시 강남구 논현로 826  135893.0  6025.0  NaN   4  NaN  127.028531  37.522223
# 9  서울특별시 강남구 논현로131길 30  135010.0  6045.0  NaN   3  NaN  127.027878  37.514144
#
# [3 rows x 39 columns]

# %%
skin_df = df[df['상권업종소분류명'].str.contains('피부|성형')]
skin_df.head(3)
# Out:
#       상가업소번호       상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명 상권업종소분류코드  \
# 8   20808534    코원성형외과  NaN         S       의료       S01       병원    S01B08
# 31  20872995  고운나라성형외과  NaN         S       의료       S01       병원    S01B08
# 44  20912401   아미가성형외과  NaN         S       의료       S01       병원    S01B08
#
#    상권업종소분류명 표준산업분류코드  ...                     건물관리번호   건물명  \
# 8   정형/성형외과   Q86201  ...  1168010700105920004010990  이가빌딩
# 31  정형/성형외과   Q86201  ...  1174010800100090005004868   NaN
# 44  정형/성형외과   Q86201  ...  1165010100109020001015305  원등빌딩
#
#                   도로명주소     구우편번호   신우편번호  동정보 층정보  호정보          경도         위도
# 8     서울특별시 강남구 논현로 826  135893.0  6025.0  NaN   4  NaN  127.028531  37.522223
# 31  서울특별시 강동구 천호대로 1032  134030.0  5379.0  NaN   3  NaN  127.126507  37.537333
# 44   서울특별시 서초구 방배로20길 4  137060.0  6664.0  NaN   3  NaN  126.995334  37.485498
#
# [3 rows x 39 columns]

# %%
skin_df_v = skin_df['시군구명'].value_counts()

# %%
skin_df_v
# Out:
# 시군구명
# 강남구     603
# 서초구     200
# 송파구      48
# 마포구      40
# 영등포구     39
# 강서구      38
# 광진구      37
# 강동구      37
# 중구       31
# 은평구      31
# 서대문구     29
# 성북구      28
# 동대문구     27
# 양천구      26
# 노원구      26
# 중랑구      21
# 성동구      17
# 구로구      17
# 관악구      17
# 동작구      14
# 강북구      12
# 종로구      11
# 용산구      10
# 금천구       9
# 도봉구       5
# Name: count, dtype: int64

# %%
total_df_v = df['시군구명'].value_counts()
total_df_v
# Out:
# 시군구명
# 강남구     2550
# 서초구     1196
# 송파구      748
# 동대문구     644
# 광진구      600
# 강서구      579
# 영등포구     516
# 은평구      506
# 노원구      503
# 강동구      494
# 성북구      470
# 마포구      456
# 중구       423
# 양천구      398
# 관악구      395
# 서대문구     379
# 종로구      343
# 동작구      342
# 성동구      339
# 중랑구      307
# 구로구      289
# 도봉구      275
# 강북구      259
# 용산구      222
# 금천구      173
# Name: count, dtype: int64

# %%
ratio = (skin_df_v / total_df_v).round(2)
ratio_sorted = ratio.sort_values(ascending=False)

# %%
ratio_sorted
# Out:
# 시군구명
# 강남구     0.24
# 서초구     0.17
# 마포구     0.09
# 영등포구    0.08
# 서대문구    0.08
# 강서구     0.07
# 강동구     0.07
# 중구      0.07
# 양천구     0.07
# 중랑구     0.07
# 성북구     0.06
# 송파구     0.06
# 구로구     0.06
# 은평구     0.06
# 광진구     0.06
# 노원구     0.05
# 성동구     0.05
# 금천구     0.05
# 용산구     0.05
# 강북구     0.05
# 동대문구    0.04
# 동작구     0.04
# 관악구     0.04
# 종로구     0.03
# 도봉구     0.02
# Name: count, dtype: float64

# %% [markdown]
# ## Q4

# %%
# !pip install folium
# Out:
# Collecting folium
#   Downloading folium-0.17.0-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting branca>=0.6.0 (from folium)
#   Downloading branca-0.7.2-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: jinja2>=2.9 in c:\users\dasap\anaconda3\envs\tf10\lib\site-packages (from folium) (3.1.4)
# Requirement already satisfied: numpy in c:\users\dasap\anaconda3\envs\tf10\lib\site-packages (from folium) (1.26.4)
# Requirement already satisfied: requests in c:\users\dasap\anaconda3\envs\tf10\lib\site-packages (from folium) (2.32.2)
# Collecting xyzservices (from folium)
#   Downloading xyzservices-2024.6.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dasap\anaconda3\envs\tf10\lib\site-packages (from jinja2>=2.9->folium) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dasap\anaconda3\envs\tf10\lib\site-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dasap\anaconda3\envs\tf10\lib\site-packages (from requests->folium) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dasap\anaconda3\envs\tf10\lib\site-packages (from requests->folium) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dasap\anaconda3\envs\tf10\lib\site-packages (from requests->folium) (2024.2.2)
# Downloading folium-0.17.0-py2.py3-none-any.whl (108 kB)
#    ---------------------------------------- 0.0/108.4 kB ? eta -:--:--
#    --- ------------------------------------ 10.2/108.4 kB ? eta -:--:--
#    ------------------------------------- -- 102.4/108.4 kB 3.0 MB/s eta 0:00:01
#    ---------------------------------------- 108.4/108.4 kB 2.1 MB/s eta 0:00:00
# Downloading branca-0.7.2-py3-none-any.whl (25 kB)
# Downloading xyzservices-2024.6.0-py3-none-any.whl (83 kB)
#    ---------------------------------------- 0.0/83.9 kB ? eta -:--:--
#    ---------------------------------------- 83.9/83.9 kB 4.6 MB/s eta 0:00:00
# Installing collected packages: xyzservices, branca, folium
# Successfully installed branca-0.7.2 folium-0.17.0 xyzservices-2024.6.0

# %%
import folium

sliver_hospitals = df[df['상권업종소분류명'].str.contains('노인|치매')]
sliver_hospitals.head(3)
# Out:
#       상가업소번호        상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명 상권업종소분류코드  \
# 21  21128898    다사랑요양병원  NaN         S       의료       S01       병원    S01B17
# 62  21511155        노경회  NaN         S       의료       S01       병원    S01B17
# 69  21406385  일산카네이션너싱홈  NaN         S       의료       S01       병원    S01B17
#
#    상권업종소분류명 표준산업분류코드  ...                     건물관리번호      건물명  \
# 21  노인/치매병원   Q86102  ...  2632010300101360002000001  다사랑요양병원
# 62  노인/치매병원   Q86102  ...  4623035023110240001000001      NaN
# 69  노인/치매병원   Q86102  ...  4128510200115610001011448   해태쇼핑타운
#
#                    도로명주소     구우편번호    신우편번호  동정보 층정보  호정보          경도  \
# 21      부산광역시 북구 덕천로 339  616110.0  46610.0  NaN   1  NaN  129.040773
# 62    전라남도 광양시 진월면 용소길 7  545851.0  57713.0  NaN   1  NaN  127.746981
# 69  경기도 고양시 일산동구 중산로 241  410831.0  10336.0  NaN   3  NaN  126.780122
#
#            위도
# 21  35.209154
# 62  34.986585
# 69  37.693689
#
# [3 rows x 39 columns]

# %%
m = folium.Map(location=[37.5, 127], zoom_start=12)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b2feb37a047d9fc637a13651abb3392e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b2feb37a047d9fc637a13651abb3392e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b2feb37a047d9fc637a13651abb3392e = L.map(
#                 &quot;map_b2feb37a047d9fc637a13651abb3392e&quot;,
#                 {
#                     center: [37.5, 127.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ef2e7cc992e75e936cd51ce7c0af57de = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ef2e7cc992e75e936cd51ce7c0af57de.addTo(map_b2feb37a047d9fc637a13651abb3392e);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
for n in sliver_hospitals.index:
    name = sliver_hospitals.loc[n, "상호명"]
    address = sliver_hospitals.loc[n, "도로명주소"]
    popup = f"{name}-{address}"
    location = [sliver_hospitals.loc[n, "위도"], sliver_hospitals.loc[n, "경도"]]
    folium.Marker(
        location = location,
        popup = popup,
    ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b2feb37a047d9fc637a13651abb3392e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b2feb37a047d9fc637a13651abb3392e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b2feb37a047d9fc637a13651abb3392e = L.map(
#                 &quot;map_b2feb37a047d9fc637a13651abb3392e&quot;,
#                 {
#                     center: [37.5, 127.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ef2e7cc992e75e936cd51ce7c0af57de = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ef2e7cc992e75e936cd51ce7c0af57de.addTo(map_b2feb37a047d9fc637a13651abb3392e);
#
#
#             tile_layer_ef2e7cc992e75e936cd51ce7c0af57de.addTo(map_b2feb37a047d9fc637a13651abb3392e);
#
#
#             var marker_cb01904602bc1de0b11928f5ca091949 = L.marker(
#                 [35.2091539574761, 129.040772964856],
#                 {}
#             ).addTo(map_b2feb37a047d9fc637a13651abb3392e);
#
#
#             var icon_08c8d4a63fcc9a2297d1c968cd58ab00 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_cb01904602bc1de0b11928f5ca091949.setIcon(icon_08c8d4a63fcc9a2297d1c968cd58ab00);
#
#
#         var popup_67dd8eeb4d5993c84c977a1f42e082ae = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_916452f124832976350e471ab4aeab71 = $(`&lt;div id=&quot;html_916452f124832976350e471ab4aeab71&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;다사랑요양병원&lt;/div&gt;`)[0];
#                 popup_67dd8eeb4d5993c84c977a1f42e082ae.setContent(html_916452f124832976350e471ab4aeab71);
#
#
#
#         marker_cb01904602bc1de0b11928f5ca091949.bindPopup(popup_67dd8eeb4d5993c84c977a1f42e082ae)
#         ;
#
#
#
#
#             var marker_20862a4afd69f9fd83efc9fbb227c8e2 = L.marker(
#                 [34.9865848568725, 127.746980976467],
#                 {}
#             ).addTo(map_b2feb37a047d9fc637a13651abb3392e);
#
#
#             var icon_77c3e1ff1e106d9e9273657278218cf8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_20862a4afd69f9fd83efc9fbb227c8e2.setIcon(icon_77c3e1ff1e106d9e9273657278218cf8);
#
#
#         var popup_03cf9b23ccd17cc47ac7566ddd949c8c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7dd575f9a83f2f1cf887e60509641784 = $(`&lt;div id=&quot;html_7dd575f9a83f2f1cf887e60509641784&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;노경회&lt;/div&gt;`)[0];
#                 popup_03cf9b23ccd17cc47ac7566ddd949c8c.setContent(html_7dd575f9a83f2f1cf887e60509641784);
#
#
#
#         marker_20862a4afd69f9fd83efc9fbb227c8e2.bindPopup(popup_03cf9b23ccd17cc47ac7566ddd949c8c)
#         ;
#
#
#
#
#             var marker_67b74de756abb14b52675a44b954568b = L.marker(
#                 [37.6936890859817, 126.780121523366],
#                 {}
#             ).addTo(map_b2feb37a047d9fc637a13651abb3392e);
#
#
#             var icon_c11a77c763a2604634f5e6da71572cc2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_67b74de756abb14b52675a44b954568b.setIcon(icon_c11a77c763a2604634f5e6da71572cc2);
#
#
#         var popup_186422c8853983f756af5bff896e4198 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7138a69bb56baa027f3921b3d3f56904 = $(`&lt;div id=&quot;html_7138a69bb56baa027f3921b3d3f56904&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;일산카네이션너싱홈&lt;/div&gt;`)[0];
#                 popup_186422c8853983f756af5bff896e4198.setContent(html_7138a69bb56baa027f3921b3d3f56904);
#
#
#
#         marker_67b74de756abb14b52675a44b954568b.bindPopup(popup_186422c8853983f756af5bff896e4198)
#         ;
#
#
#
#
#             var marker_1c3d275be0824834e519718fdf320181 = L.marker(
#                 [34.9910140897983, 127.460606294325],
#                 {}
#             ).addTo(map_b2feb37a047d9fc637a13651abb3392e);
#
#
#             var icon_08f42b9db31f31a27fce22266a1af65e = L.AwesomeMarkers.icon(
